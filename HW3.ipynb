# %%
# The homework has been done by this tutorial
#http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_imgproc/py_morphological_ops/py_morphological_ops.html

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# Loading an image
#img = cv2.imread('j.png', 0)
img1 = cv2.imread('car1.jpg', 0)
img2 = cv2.imread('car2.jpg', 0)
img3 = cv2.imread('car3.jpg', 0)
img4 = cv2.imread('car4.jpg', 0)
img5 = cv2.imread('car5.jpg', 0)
img6 = cv2.imread('car6.jpg', 0)
img7 = cv2.imread('car7.jpg', 0)
img8 = cv2.imread('car8.jpg', 0)
img9 = cv2.imread('m1.jpg', 0)
img10 = cv2.imread('m2.jpg', 0)
img11 = cv2.imread('m3.jpg', 0)

# Creating a ROI (region of interest)
ROI1 = img1[720:1030, 450:1100]
ROI2 = img2[670:960, 700:1276]
ROI3 = img3[532:802, 690:1133]
ROI4 = img4[557:826, 876:1410]
ROI5 = img5[790:1089, 310:1075]
ROI6 = img6[812:1096, 296:1049]
ROI7 = img7[740:1000, 505:1097]
ROI8 = img8[760:887, 1022:1289]
ROI9 = img9[1414:1555, 1093:1425]
ROI10 = img10[880:955, 596:759]
ROI11 = img11[1540:1690, 1111:1423]

# Showing an image
#cv2.imshow('img1', img1)
#cv2.imshow('img2', img2)
#cv2.imshow('img3', img3)
#cv2.imshow('img4', img4)
#cv2.imshow('img5', img5)
#cv2.imshow('img6', img6)
#cv2.imshow('img7', img7)
#cv2.imshow('img8', img8)
#cv2.imshow('img9', img9)
#cv2.imshow('img10', img10)
#cv2.imshow('img11', img11)

#cv2.imshow('ROI1', ROI1)
#cv2.imshow('ROI2', ROI2)
#cv2.imshow('ROI3', ROI3)
#cv2.imshow('ROI4', ROI4)
#cv2.imshow('ROI5', ROI5)
#cv2.imshow('ROI6', ROI6)
#cv2.imshow('ROI7', ROI7)
#cv2.imshow('ROI8', ROI8)
#cv2.imshow('ROI9', ROI9)
#cv2.imshow('ROI10', ROI10)
#cv2.imshow('ROI11', ROI11)


cv2.waitKey(0)
cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1.png', ROI1)
cv2.imwrite('ROI2.png', ROI2)
cv2.imwrite('ROI3.png', ROI3)
cv2.imwrite('ROI4.png', ROI4)
cv2.imwrite('ROI5.png', ROI5)
cv2.imwrite('ROI6.png', ROI6)
cv2.imwrite('ROI7.png', ROI7)
cv2.imwrite('ROI8.png', ROI8)
cv2.imwrite('ROI9.png', ROI9)
cv2.imwrite('ROI10.png', ROI10)
cv2.imwrite('ROI11.png', ROI11)
# Out:
# True

# %%
img2.shape
# Out:
# (1536, 2048)

# %%
def imshow(image):      
    cv2.imshow('image', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    return

# %%
imshow(ROI11)

# %%
# Asighnig kernel
kernel = np.ones((5, 5),np.uint8)

# %%
# 1 DEF Erosion
#kernel = np.ones((9, 9),np.uint8)
def erosion(image):
    calculate_erosion = cv2.erode(image, kernel, iterations = 1)
    return calculate_erosion;

plt.subplot(121),plt.imshow(ROI1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(erosion(ROI1),cmap = 'gray')
plt.title('After applying Erosion operation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#cv2.imshow('erosion', erosion(ROI1))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1_erosion.png', erosion(ROI1))
# Out:
# True

# %%
# 2 DEF Dilation
def dilation(image):
    #calculate_dilation = cv2.dilate(image, kernel, iterations = 1)
    calculate_dilation = cv2.dilate(erosion(image), kernel, iterations = 1) 
    return calculate_dilation;

plt.subplot(121),plt.imshow(ROI2,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dilation(ROI2),cmap = 'gray')
plt.title('After applying Dilation operation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI2)
#cv2.imshow('dilation', dilation(ROI2))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1_dilation.png', dilation(ROI2))
# Out:
# True

# %%
# 3 An example for Opening
img_opening = cv2.imread('opening.png', 0)
img_opening_ROI1 = img_opening[0:150, 0:112]

opening = cv2.morphologyEx(img_opening_ROI1, cv2.MORPH_OPEN, kernel)

plt.subplot(121),plt.imshow(img_opening_ROI1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(opening,cmap = 'gray')
plt.title('After applying opening operation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', img_opening_ROI1)
#cv2.imshow('opening', opening)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# 3 DEF Opening
def opening(image):
    calculate_opening = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
    return calculate_opening;

plt.subplot(121),plt.imshow(ROI3,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(opening(ROI3),cmap = 'gray')
plt.title('After applying opening opereation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#cv2.imshow('opening', opening(ROI1))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI3_opening.png', opening(ROI3))
# Out:
# True

# %%
#imshow(opening(ROI2))

# %%
# 4 An example for Closing
img_closing = cv2.imread('closing.png', 0)
img_closing_ROI1 = img_closing[0:150, 0:112]
closing = cv2.morphologyEx(img_closing_ROI1, cv2.MORPH_CLOSE, kernel)

plt.subplot(121),plt.imshow(img_closing_ROI1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(closing,cmap = 'gray')
plt.title('After applying closing operation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', img_closing_ROI1)
#cv2.imshow('closing', closing)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# 4 DEF Closing
def closing(image):
    calculate_closing = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)
    return calculate_closing;

plt.subplot(121),plt.imshow(ROI4,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(closing(ROI4),cmap = 'gray')
plt.title('After applying closing opereation'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#cv2.imshow('closing', closing(ROI1))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI4_closing.png', closing(ROI4))
# Out:
# True

# %%
# 5 DEF Morphological Gradient
def gradient(image):
    calculate_gradient = cv2.morphologyEx(image, cv2.MORPH_GRADIENT, kernel)
    return calculate_gradient;

plt.subplot(121),plt.imshow(ROI11,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(gradient(ROI11),cmap = 'gray')
plt.title('After applying Morphological Gradient'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#cv2.imshow('gradient', gradient(ROI1))
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1_gradient.png', gradient(ROI11))
# Out:
# True

# %%
# 6 An example for Top Hat
img = cv2.imread('j.png', 0)
kernel = np.ones((9, 9),np.uint8)
tophat = cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernel)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(tophat,cmap = 'gray')
plt.title('After applying Top Hat'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', img)
#cv2.imshow('tophat', tophat)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# 6 Top Hat
kernel = np.ones((9, 9),np.uint8)
tophat = cv2.morphologyEx(ROI1, cv2.MORPH_TOPHAT, kernel)


plt.subplot(121),plt.imshow(ROI1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(tophat,cmap = 'gray')
plt.title('After applying Top Hat'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#v2.imshow('tophat', tophat)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1_tophat.png', tophat)
# Out:
# True

# %%
# 7 An example for Black Hat
img = cv2.imread('j.png', 0)
kernel = np.ones((9, 9),np.uint8)
blackhat = cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernel)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blackhat,cmap = 'gray')
plt.title('After applying Black Hat'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', img)
#cv2.imshow('blackhat', blackhat)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# %%
# 7 Black Hat
kernel = np.ones((9, 9),np.uint8)
blackhat = cv2.morphologyEx(ROI1, cv2.MORPH_BLACKHAT, kernel)

plt.subplot(121),plt.imshow(ROI1,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blackhat,cmap = 'gray')
plt.title('After applying Black Hat'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('original', ROI1)
#cv2.imshow('blackhat', blackhat)
#cv2.waitKey(0)
#cv2.destroyAllWindows()

# Saving images
cv2.imwrite('ROI1_blackhat.png', blackhat)
# Out:
# True

# %%
# Canny Edge Detection
import cv2
import numpy as np
from matplotlib import pyplot as plt
#img = cv2.imread('messi5.jpg',0)
img = cv2.imread('car1.jpg',0)
edges = cv2.Canny(ROI1,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

#cv2.imshow('edges', edges)
#cv2.waitKey(0)
#cv2.destroyAllWindows()
